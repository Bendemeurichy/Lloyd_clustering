# %% [markdown]
# # Dask client setup

# %%
from dask.distributed import LocalCluster
cluster = LocalCluster()          # Fully-featured local Dask cluster
client = cluster.get_client()
client
# Out:
# /home/bendm/compbio/Lloyd_clustering/.venv/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40349 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:35369' processes=4 threads=16, memory=14.86 GiB>

# %%
import sys
sys.path.insert(1,'../algorithms')

import lloyd_clus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import lloyd_clustering as lloyd
#
# ModuleNotFoundError: No module named 'lloyd_clustering'

# %% [markdown]
# # Generate data
